# %% [markdown]
# # Question 1 :
#
# ## Define Object Oriented Programming Language ?
#
# # Answer :
#
# ## Object-oriented programming is a programming paradigm based on the concept of objects, which can contain data, in the form of fields, and code, in the form of procedures. A feature of objects is an object's procedures that can access and often modify the data fields of the object with which they are associated.

# %% [markdown]
# # Question 2 :
#
# ## List down the benifits of OOP ?
#
# # Answer :
#
# ## * It provides a clear modular structure for programs which makes it good for defining abstract datatypes in which implementation details are hidden.
#
# ## * Objects can also be reused within an across applications. The reuse of software also lowers the cost of development. More effort is put into the object-oriented analysis and design, which lowers the overall cost of development.
#
# ## * It makes software easier to maintain. Since the design is modular, part of the system can be updated in case of issues without a need to make large-scale changes.
#
# ## * Reuse also enables faster development.Object-oriented programming languages come with rich libraries of objects, and code developed during projects is also reusable in future projects.
#
# ## * It provides a good framework for code libraries where the supplied software components can be easily adapted and modified by the programmer.This is particularly useful for developing graphical user interfaces (GUI).
#
# ## * Better Productivity as OOP techniques enforce rules on a programmer that, in the long run, help her get more work done, finished programs work better, have more features and are easier to read and maintain.

# %% [markdown]
# # Question 3 :
#
# ## Differentiate between function and method ?
#
# # Answer :
#
# ## Python method is called on an object, unlike a function, Since we call a method on an object, it can access the data within it.A method may alter an object's state , but Python function usually only operates on it and then prints something or returns a value.

# %% [markdown]
# # Question 4 :
#
# ## Define the following terms :
#
# ## 1. Class
# ## 2. Object
# ## 3. Attribute
# ## 4. Behaviour
#
# # Answer :
#
# # Class :
#
# ## A class is a code template for creating objects. Objects have member variables and have behaviour associated with them.In python a class is created by the keyword class. An object is created using the constructor of the class. This object will then be called the instance of the class.
#
# # Object :
#
# ## Python is an object-oriented programming language, This defines a set of attributes that will characterize any object that is instantiated from this class. Object — An instance of a class. This is the realized version of the class, where the class is manifested in the program.
#
# # Attribute :
#
# ## An instance attribute is a Python variable belonging to one and only one object. A class attribute is a Python variable that belongs to a class rather than a particular object. It is shared between all the objects of this class and it is defined outside the constructor function of the class.
#
# # Behaviour :
#
# ## Objects in Python are generally classified according to their behaviors and the features that they implement. For example, all of the sequence types such as strings, lists, and tuples are grouped together merely because they all happen to support a common set of sequence operations

# %%
class Car():
    def __init__(self,name,model,colour,doors,fuel):
        self.name = name
        self.model = model
        self.colour = colour
        self.doors = doors
        self.fuel = fuel

    def average(self,kilo):
        print("Average :",kilo,"Kilometers Per Liter")

    def speed(self,kilo):
        print("Speed :",kilo,"Kilometers Per Hour")
        
    def nitro(self,kilo):
        print("Nitro :",kilo,"Meters Per sec")

car_1 = Car("Mercedes-Benz","Maybach","White","4","30")
car_2 = Car("BMW","M8 Gran Coupe","Grey","4","25")
car_3 = Car("Ferrari","Tributo","Red","2","20")
car_4 = Car("Mazda","MX-5","Green","2","15")
car_5 = Car("Audi","Q8","Black","4","10")

def car_10():
    print("Name :",car_1.name)
    print("Model :",car_1.model)
    print("Colour :",car_1.colour)
    car_1.average(30)
    car_1.speed(30)
    car_1.nitro(30)

def car_20():
    print("Name :",car_2.name)
    print("Model :",car_2.model)
    print("Colour :",car_2.colour)
    car_1.average(25)
    car_1.speed(25)
    car_1.nitro(25)    

def car_30():
    print("Name :",car_3.name)
    print("Model :",car_3.model)
    print("Colour :",car_3.colour)
    car_1.average(20)
    car_1.speed(20)
    car_1.nitro(20)

def car_40():
    print("Name :",car_4.name)
    print("Model :",car_4.model)
    print("Colour :",car_4.colour)
    car_1.average(15)
    car_1.speed(15)
    car_1.nitro(15)

def car_50():
    print("Name :",car_5.name)
    print("Model :",car_5.model)
    print("Colour :",car_5.colour)
    car_1.average(10)
    car_1.speed(10)
    car_1.nitro(10)

car_10()
print("--------------------------------------")
car_20()
print("--------------------------------------")
car_30()
print("--------------------------------------")
car_40()
print("--------------------------------------")
car_50()
# Out:
# Name : Mercedes-Benz
# Model : Maybach
# Colour : White
# Average : 30 Kilometers Per Liter
# Speed : 30 Kilometers Per Hour
# Nitro : 30 Meters Per sec
# --------------------------------------
# Name : BMW
# Model : M8 Gran Coupe
# Colour : Grey
# Average : 25 Kilometers Per Liter
# Speed : 25 Kilometers Per Hour
# Nitro : 25 Meters Per sec
# --------------------------------------
# Name : Ferrari
# Model : Tributo
# Colour : Red
# Average : 20 Kilometers Per Liter
# Speed : 20 Kilometers Per Hour
# Nitro : 20 Meters Per sec
# --------------------------------------
# Name : Mazda
# Model : MX-5
# Colour : Green
# Average : 15 Kilometers Per Liter
# Speed : 15 Kilometers Per Hour
# Nitro : 15 Meters Per sec
# --------------------------------------
# Name : Audi
# Model : Q8
# Colour : Black
# Average : 10 Kilometers Per Liter
# Speed : 10 Kilometers Per Hour
# Nitro : 10 Meters Per sec
